# %% [markdown]
# # CE541E08 — Introduction to Python and MATLAB Programming
# ## Unit 1 · Day 2 — Elements of Python Language
#
# ---
#
# | | |
# |---|---|
# | **Course** | CE541E08 |
# | **Department** | Civil Engineering · Christ University |
# | **Instructor** | Dr. Arpan Pradhan |
# | **Unit** | Unit 1 |
# | **Session** | Day 2 |
# | **CO** | CO1 |
# | **Topics today** | Syntax · indentation · comments · block structure · import · pipe cross-section |
#
# ---
# > Run each grey code cell with **Shift + Enter**. Read the explanation above each cell first.
# > Instructor notes are marked `─── INSTRUCTOR NOTE ───`.
# ---

# %%
# STUDENT HEADER — fill in before starting
student_name = "Daniel Lungouchuon Haokip"
roll_number  = "2460108"
github_repo  = "https://github.com/daniellungouchon-art/CE541E08-2026"
session      = "Day 2"
print("╔══════════════════════════════════════════╗")
print("║         CE541E08 — Student Record         ║")
print("╠══════════════════════════════════════════╣")
print(f"║  Name    : {student_name:<31}║")
print(f"║  Roll    : {roll_number:<31}║")
print(f"║  Session : {session:<31}║")
print("╚══════════════════════════════════════════╝")
# Out:
# ╔══════════════════════════════════════════╗
# ║         CE541E08 — Student Record         ║
# ╠══════════════════════════════════════════╣
# ║  Name    : Daniel Lungouchuon Haokip      ║
# ║  Roll    : 2460108                        ║
# ║  Session : Day 2                          ║
# ╚══════════════════════════════════════════╝

# %% [markdown]
# ## Section 1 — The four rules of Python syntax
#
# | Rule | What it means |
# |---|---|
# | **Indentation** | Spaces at the start define code blocks — not decoration |
# | **Case-sensitive** | `Area` ≠ `area` |
# | **Colon** | `:` starts every new block (if, for, def) |
# | **Hash `#`** | Everything after # is a comment — Python ignores it |
#
# > *"Python reads your indentation like a civil engineer reads a cross-section — the spacing IS the structure."*

# %% [markdown]
# ### ▶ Cell 1 — Correct syntax and common mistakes

# %%
# Correct Python — run this cell (Shift+Enter)
pipe_diameter = 0.3          # float — decimal number
pipe_material = "concrete"   # string — text in quotes
pipe_full     = True         # bool — capital T

print("Diameter :", pipe_diameter, "m")
print("Material :", pipe_material)
print("Full pipe?", pipe_full)

# ─── INSTRUCTOR NOTE ───────────────────────────────────────────
# Ask: what happens if you write true instead of True?
# Demo: change to true → NameError (case sensitive)
# ───────────────────────────────────────────────────────────────
# Out:
# Diameter : 0.3 m
# Material : concrete
# Full pipe? True

# %% [markdown]
# ## Section 2 — Python block structure and import
#
# ```python
# if condition:        # colon starts the block
#     do_something()   # indented = inside the block
# outside_block()      # not indented = always runs
# ```
#
# `import math` loads Python's maths toolkit: π, sqrt, trig functions.

# %% [markdown]
# ### ▶ Cell 2 — Block structure with a pipe check

# %%
pipe_diameter = 0.3

if pipe_diameter >= 0.1:          # block starts here
    print("Meets minimum diameter requirement.")
    import math
    area = math.pi * (pipe_diameter/2)**2
    print(f"Cross-sectional area: {round(area,4)} m²")

print("Check complete.")           # always runs

# ─── INSTRUCTOR NOTE ───────────────────────────────────────────
# Try pipe_diameter = 0.05 — the indented block is skipped.
# "Check complete." always runs because it is not indented.
# ───────────────────────────────────────────────────────────────
# Out:
# Meets minimum diameter requirement.
# Cross-sectional area: 0.0707 m²
# Check complete.

# %% [markdown]
# ### ▶ Cell 3 — import math: pipe geometry with exact π

# %%
import math

diameter = 0.6        # 600 mm trunk main
radius   = diameter / 2
area     = math.pi * radius**2
perim    = math.pi * diameter
R        = area / perim           # hydraulic radius = D/4

print(f"Diameter         : {diameter*1000:.0f} mm")
print(f"Area             : {area:.6f} m²")
print(f"Wetted perimeter : {perim:.6f} m")
print(f"Hydraulic radius : {R:.6f} m")
print(f"D/4 check        : {diameter/4:.6f} m ✓")

# ─── INSTRUCTOR NOTE ───────────────────────────────────────────
# Hydraulic radius of a full circular pipe = D/4.
# Proof: R = A/P = (πD²/4)/(πD) = D/4.
# This is used in Manning's equation.
# ───────────────────────────────────────────────────────────────
# Out:
# Diameter         : 600 mm
# Area             : 0.282743 m²
# Wetted perimeter : 1.884956 m
# Hydraulic radius : 0.150000 m
# D/4 check        : 0.150000 m ✓

# %% [markdown]
# ### ▶ Cell 4 — A complete, well-structured engineering script

# %%
# ═══════════════════════════════════════════════════
# Script  : Circular Pipe Cross-Section Calculator
# Author  : CE541E08 Student
# Purpose : Compute geometric properties of a pipe
# ═══════════════════════════════════════════════════
import math

# ── INPUTS ──────────────────────────────────────────
diameter_mm = 450          # pipe diameter, mm
# ────────────────────────────────────────────────────

diameter = diameter_mm / 1000
area     = math.pi * (diameter/2)**2
perim    = math.pi * diameter
R        = area / perim

print(f"Diameter         : {diameter_mm} mm  ({diameter} m)")
print(f"Cross-section    : {area:.4f} m²")
print(f"Wetted perimeter : {perim:.4f} m")
print(f"Hydraulic radius : {R:.4f} m")

# ─── INSTRUCTOR NOTE ───────────────────────────────
# Target format for ALL student submissions.
# Header → Inputs with units → Calculations → Output.
# ───────────────────────────────────────────────────
# Out:
# Diameter         : 450 mm  (0.45 m)
# Cross-section    : 0.1590 m²
# Wetted perimeter : 1.4137 m
# Hydraulic radius : 0.1125 m

# %% [markdown]
# ---
# ## Day 2 Assignment
# A **rectangular open channel**: B = 3.5 m, y = 1.2 m.
# Write a complete script computing: A = B×y, P = B+2y, R = A/P, hydraulic depth D = A/B.
# Include a proper header, label all inputs with units, format all outputs.
# *(Answers: A=4.2 m², P=5.9 m, R=0.7119 m, D=1.2 m)*

# %% [markdown]
# ### ▶ Assignment cell

# %%
# ═══════════════════════════════════════════════════
# Script  : Rectangular Channel Cross-Section
# Author  : [Your Name]
# ═══════════════════════════════════════════════════
import math

# --- INPUTS ----------------------------------------
B = 3.5    # m
y = 1.2    # m
# ---------------------------------------------------

# --- CALCULATIONS ----------------------------------
A = B * y
P = B + 2 * y
R = A / P
D = A / B    # hydraulic depth = A/T where T=B for rectangular
# ---------------------------------------------------

# --- OUTPUTS ---------------------------------------
print(f"Width B        : {B} m")
print(f"Depth y        : {y} m")
print(f"Area A         : {round(A,4)} m²")
print(f"Perimeter P    : {round(P,4)} m")
print(f"Hyd. radius R  : {round(R,4)} m")
print(f"Hyd. depth D   : {round(D,4)} m")
# ---------------------------------------------------
# Out:
# Width B        : 3.5 m
# Depth y        : 1.2 m
# Area A         : 4.2 m²
# Perimeter P    : 5.9 m
# Hyd. radius R  : 0.7119 m
# Hyd. depth D   : 1.2 m

# %% [markdown]
# ---
# ## Before next session — checklist
# - [ ] Completed all assignment cells
# - [ ] Saved notebook to Google Drive
# - [ ] Uploaded to GitHub: `Unit1_PythonBasics/CE541E08_U1_Day2.ipynb`
# - [ ] Commit message: `Day 2 assignment completed`
#
# ---
# *CE541E08 · Civil Engineering · Christ University · 2026–27 · Dr. Arpan Pradhan · arpan.pradhan@christuniversity.in*
